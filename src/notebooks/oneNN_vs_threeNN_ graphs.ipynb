# %%
import matplotlib.pyplot as plt

data = [(1,0),(1,4),(3,3),(-1,1),(-1,-1),(0,2)]
labels = [1, 1, 1, -1, -1, -1]

test_sample = [(1,2)]

# Convert data to x and y for plotting
x, y = zip(*data)

# Separating data based on labels
x_pos = [xi for xi, label in zip(x, labels) if label == 1]
y_pos = [yi for yi, label in zip(y, labels) if label == 1]
x_neg = [xi for xi, label in zip(x, labels) if label == -1]
y_neg = [yi for yi, label in zip(y, labels) if label == -1]

# Plotting data points with labels 1 and -1
plt.scatter(x_pos, y_pos, color='blue', label='Label 1')
plt.scatter(x_neg, y_neg, color='red', label='Label -1')

# Plotting test sample
plt.scatter(*test_sample[0], color='green', marker='*', s=100, label='Test Sample')

# Adjusting the axis to show integer ticks
plt.xticks(range(int(min(x)) - 1, int(max(x)) + 2))
plt.yticks(range(int(min(y)) - 1, int(max(y)) + 2))

# Displaying the axis
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Data NN')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

data = [(1,0),(1,4),(3,3),(-1,1),(-1,-1),(0,2)]
labels = [1, 1, 1, -1, -1, -1]

test_sample = [(1,2)]

# Convert data to x and y for plotting
x, y = zip(*data)

# Separating data based on labels
x_pos = [xi for xi, label in zip(x, labels) if label == 1]
y_pos = [yi for yi, label in zip(y, labels) if label == 1]
x_neg = [xi for xi, label in zip(x, labels) if label == -1]
y_neg = [yi for yi, label in zip(y, labels) if label == -1]

# Plotting data points with labels 1 and -1
plt.scatter(x_pos, y_pos, color='blue', label='Label 1')
plt.scatter(x_neg, y_neg, color='red', label='Label -1')

# Plotting test sample
plt.scatter(*test_sample[0], color='red', marker='*', s=100, label='Test Sample')

# Adjusting the axis to show integer ticks
plt.xticks(range(int(min(x)) - 1, int(max(x)) + 2))
plt.yticks(range(int(min(y)) - 1, int(max(y)) + 2))

# Displaying the axis
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('1NN Prediction')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

data = [(1,0),(1,4),(3,3),(-1,1),(-1,-1),(0,2)]
labels = [1, 1, 1, -1, -1, -1]

test_sample = [(1,2)]

# Convert data to x and y for plotting
x, y = zip(*data)

# Separating data based on labels
x_pos = [xi for xi, label in zip(x, labels) if label == 1]
y_pos = [yi for yi, label in zip(y, labels) if label == 1]
x_neg = [xi for xi, label in zip(x, labels) if label == -1]
y_neg = [yi for yi, label in zip(y, labels) if label == -1]

# Plotting data points with labels 1 and -1
plt.scatter(x_pos, y_pos, color='blue', label='Label 1')
plt.scatter(x_neg, y_neg, color='red', label='Label -1')

# Plotting test sample
plt.scatter(*test_sample[0], color='blue', marker='*', s=100, label='Test Sample')

# Adjusting the axis to show integer ticks
plt.xticks(range(int(min(x)) - 1, int(max(x)) + 2))
plt.yticks(range(int(min(y)) - 1, int(max(y)) + 2))

# Displaying the axis
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('3NN Prediction')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to calculate Euclidean distance
def euclidean_distance(point1, point2):
    return np.sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)

# Your data and test sample
data = [(1, 0), (1, 4), (3, 3), (-1, 1), (-1, -1), (0, 2)]
labels = [1, 1, 1, -1, -1, -1]
test_sample = (1, 2)

# Calculate distances from the test sample to each data point
distances = [euclidean_distance(point, test_sample) for point in data]

# Finding the nearest neighbor
nearest_neighbor_idx = np.argmin(distances)
nearest_neighbor = data[nearest_neighbor_idx]
distance_to_nearest_neighbor = distances[nearest_neighbor_idx]

# Separating data based on labels for plotting
x, y = zip(*data)
x_pos = [xi for xi, label in zip(x, labels) if label == 1]
y_pos = [yi for yi, label in zip(y, labels) if label == 1]
x_neg = [xi for xi, label in zip(x, labels) if label == -1]
y_neg = [yi for yi, label in zip(y, labels) if label == -1]

# Plotting data points with labels 1 and -1
plt.scatter(x_pos, y_pos, color='blue', label='Label 1')
plt.scatter(x_neg, y_neg, color='red', label='Label -1')

# Plotting test sample
plt.scatter(*test_sample, color='red', marker='*', s=100, label='Test Sample')

# Drawing a dashed circle around the test sample
circle = plt.Circle(test_sample, distance_to_nearest_neighbor, color='black', fill=False, linestyle='dashed')
plt.gca().add_patch(circle)

plt.plot([test_sample[0], nearest_neighbor[0]], [test_sample[1], nearest_neighbor[1]], 'k--')


# Adjusting the axis to show integer ticks and displaying the axis
plt.xticks(range(int(min(x)) - 1, int(max(x)) + 2))
plt.yticks(range(int(min(y)) - 1, int(max(y)) + 2))
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('1NN Prediction')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to calculate Euclidean distance
def euclidean_distance(point1, point2):
    return np.sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)

# Your data and test sample
data = [(1, 0), (1, 4), (3, 3), (-1, 1), (-1, -1), (0, 2)]
labels = [1, 1, 1, -1, -1, -1]
test_sample = (1, 2)

# Calculate distances from the test sample to each data point
distances = [euclidean_distance(point, test_sample) for point in data]

# Finding the nearest neighbor
nearest_neighbor_idx = np.argmin(distances)
nearest_neighbor = data[nearest_neighbor_idx]
distance_to_nearest_neighbor = distances[nearest_neighbor_idx]

# Separating data based on labels for plotting
x, y = zip(*data)
x_pos = [xi for xi, label in zip(x, labels) if label == 1]
y_pos = [yi for yi, label in zip(y, labels) if label == 1]
x_neg = [xi for xi, label in zip(x, labels) if label == -1]
y_neg = [yi for yi, label in zip(y, labels) if label == -1]

# Plotting data points with labels 1 and -1
plt.scatter(x_pos, y_pos, color='blue', label='Label 1')
plt.scatter(x_neg, y_neg, color='red', label='Label -1')

# Plotting test sample
plt.scatter(*test_sample, color='blue', marker='*', s=100, label='Test Sample')

# Drawing a dashed circle around the test sample
circle = plt.Circle(test_sample, distance_to_nearest_neighbor+1, color='black', fill=False, linestyle='dashed')
plt.gca().add_patch(circle)

# Adjusting the axis to show integer ticks and displaying the axis
plt.xticks(range(int(min(x)) - 1, int(max(x)) + 2))
plt.yticks(range(int(min(y)) - 1, int(max(y)) + 2))
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('3NN Prediction')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to calculate Euclidean distance
def euclidean_distance(point1, point2):
    return np.sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)

# Your data and test sample
data = [(1, 0), (1, 4), (3, 3), (-1, 1), (-1, -1), (0, 2)]
labels = [1, 1, 1, -1, -1, -1]
test_sample = (1, 2)

# Calculate distances from the test sample to each data point
distances = [euclidean_distance(point, test_sample) for point in data]

# Sorting indices based on distances and finding the three nearest neighbors
sorted_indices = np.argsort(distances)
three_nearest_neighbors_indices = sorted_indices[:3]
three_nearest_neighbors = [data[i] for i in three_nearest_neighbors_indices]

# Separating data based on labels for plotting
x, y = zip(*data)
x_pos = [xi for xi, label in zip(x, labels) if label == 1]
y_pos = [yi for yi, label in zip(y, labels) if label == 1]
x_neg = [xi for xi, label in zip(x, labels) if label == -1]
y_neg = [yi for yi, label in zip(y, labels) if label == -1]

# Plotting data points with labels 1 and -1
plt.scatter(x_pos, y_pos, color='blue', label='Label 1')
plt.scatter(x_neg, y_neg, color='red', label='Label -1')

# Plotting test sample
plt.scatter(*test_sample, color='blue', marker='*', s=100, label='Test Sample')

# Drawing dashed lines to the three nearest neighbors
for neighbor in three_nearest_neighbors:
    plt.plot([test_sample[0], neighbor[0]], [test_sample[1], neighbor[1]], 'k--')

# Drawing a dashed circle around the test sample
distance_to_farthest_neighbor = distances[three_nearest_neighbors_indices[2]]
circle = plt.Circle(test_sample, distance_to_farthest_neighbor, color='black', fill=False, linestyle='dashed')
plt.gca().add_patch(circle)

# Adjusting the axis to show integer ticks and displaying the axis
plt.xticks(range(int(min(x)) - 1, int(max(x)) + 2))
plt.yticks(range(int(min(y)) - 1, int(max(y)) + 2))
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('3NN Prediction')
plt.grid(True)
plt.show()
